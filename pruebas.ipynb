# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

CLIENT_ID = '04f685005f584087a8cd9fada4a373f5'
CLIENT_SECRET = '95e82b9914dc42e2a82ab0132df82dfb'


# Set up the Spotify API client
client_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# Function to get all rock tracks from 2019
def get_all_rock_tracks_2019():
    all_tracks = []
    limit = 50
    offset = 0

    while True:
        # Search for tracks
        results = sp.search(q="genre:rock year:2019", type='track', limit=limit, offset=offset)
        tracks = results['tracks']['items']
        
        if not tracks:
            break
        
        all_tracks.extend(tracks)
        offset += limit

    return all_tracks

# Get all rock tracks from 2019
rock_tracks_2019 = get_all_rock_tracks_2019()

# Print the track names
for track in rock_tracks_2019:
    print(track['name'])

# Optionally, you can print other details like artist name, album name, etc.
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/search with Params: {'q': 'genre:rock year:2019', 'limit': 50, 'offset': 1000, 'type': 'track', 'market': None} returned 400 due to Limit + Offset exceeds maximum of 1000
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\aleiv\anaconda3\Lib\site-packages\spotipy\client.py:274, in Spotify._internal_call(self, method, url, payload, params)
#     269 response = self._session.request(
#     270     method, url, headers=headers, proxies=self.proxies,
#     271     timeout=self.requests_timeout, **args
#     272 )
# --> 274 response.raise_for_status()
#     275 results = response.json()
#
# File c:\Users\aleiv\anaconda3\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# ...

# %%
# Function to get all rock tracks from 2019
def get_all_rock_tracks_2019():
    all_tracks = []
    limit = 50
    offset = 0

    while True:
        results = sp.search(q="genre:rock year:2019", type='track', limit=limit, offset=offset)
        tracks = results['tracks']['items']

        if not tracks:
            break

        all_tracks.extend(tracks)
        offset += limit

# Check if we've reached the API limit
        if offset >= 1000:
            break

    return all_tracks

# Get all rock tracks from 2019
rock_tracks_2019 = get_all_rock_tracks_2019()

# Print the track names
for track in rock_tracks_2019:
    print(track['name'])
# Out:
# Deutschland
# Ja vi elsker (Typisk Norsk 2019)
# Almost (Sweet Music)
# Mary On A Cross
# Ausländer
# Heads Will Roll - A-Trak Remix Radio Edit
# Would That I
# Radio
# Simple
# Movement
# Rosa
# A Whiter Shade of Pale - Original Single Version
# Zeig dich
# Unsainted
# Can I Call You Tonight?
# I Am Above
# Last Day Under The Sun
# Pneuma
# Heartache Medication
# Ærlig tjuv
# Rescue Me
# Leviathan
# Shrike
# Die To Live
# Kiss The Go-Goat
# Runnin' Down A Dream
# Stay with Me
# Living On My Own - No More Brothers Radio Mix
# Make You Mine
# Ten Feet off the Ground
# Keen
# Nero Forte
# Stjernesludd
# Balladen Om Deg (Acoustic)
# Me Without You - Acoustic
# Was ich liebe
# Hypersonic Missiles
# Pelvis On Fire
# Puppe
# What About Me?
# Viva La Victoria
# Master
# Deutschland
# Talk
# 7:24
# King Kong justice
# Bury My Bones
# Ein gong
# The Kid I Used to Know
# I Dette Huset (Acoustic)
# Tattoo
# Hot Rod
# Not
# Natta Som Er Over Nå
# Invincible
# Cheapside Sloggers
# ...
